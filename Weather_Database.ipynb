# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\siriu\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\siriu\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
# Import the time library and the datetime module from the datetime library 
import time

# %%
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Add the latitudes and longitudes to a list.
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
lat_lngs

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 745

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city1=cities[:20]

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in the list.
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0][ "description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | moss point
# Processing Record 2 of Set 1 | ahipara
# Processing Record 3 of Set 1 | karpathos
# Processing Record 4 of Set 1 | portlethen
# Processing Record 5 of Set 1 | batagay
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | vitoria da conquista
# Processing Record 10 of Set 1 | khor
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | belen
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | rawson
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | siavonga
# Processing Record 19 of Set 1 | fairbanks
# Processing Record 20 of Set 1 | benghazi
# Processing Record 21 of Set 1 | yabrud
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | komsomolskiy
# Processing Record 25 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | khandagayty
# Processing Record 29 of Set 1 | kloulklubed
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | tamiahua
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | juneau
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | port hardy
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | ushtobe
# Processing Record 39 of Set 1 | shingu
# Processing Record 40 of Set 1 | verkhnevilyuysk
# Processing Record 41 of Set 1 | sinnamary
# Processing Record 42 of Set 1 | coahuayana
# Processing Record 43 of Set 1 | nizhniy kuranakh
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | saint-francois
# Processing Record 48 of Set 1 | matadi
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | taoudenni
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | orumiyeh
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | laguna
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | karaman
# Processing Record 11 of Set 2 | storforshei
# Processing Record 12 of Set 2 | vila franca do campo
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | rosetta
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | namatanai
# Processing Record 21 of Set 2 | altay
# Processing Record 22 of Set 2 | olga
# Processing Record 23 of Set 2 | vardo
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | honningsvag
# Processing Record 27 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 2 | ankang
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | mount isa
# Processing Record 31 of Set 2 | huron
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | elbrus
# Processing Record 36 of Set 2 | wamba
# Processing Record 37 of Set 2 | spring hill
# Processing Record 38 of Set 2 | hofn
# Processing Record 39 of Set 2 | ancud
# Processing Record 40 of Set 2 | abu zabad
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | boyabat
# Processing Record 44 of Set 2 | varhaug
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | vanimo
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | leningradskiy
# Processing Record 4 of Set 3 | pringsewu
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | sydney
# Processing Record 7 of Set 3 | sapao
# City not found. Skipping...
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | barkot
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | alta floresta
# Processing Record 16 of Set 3 | of
# City not found. Skipping...
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | cayenne
# Processing Record 21 of Set 3 | peniche
# Processing Record 22 of Set 3 | isiro
# Processing Record 23 of Set 3 | gayeri
# Processing Record 24 of Set 3 | ngunguru
# Processing Record 25 of Set 3 | hailar
# Processing Record 26 of Set 3 | axim
# Processing Record 27 of Set 3 | ilulissat
# Processing Record 28 of Set 3 | rio grande
# Processing Record 29 of Set 3 | airai
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | sept-iles
# Processing Record 32 of Set 3 | aflao
# Processing Record 33 of Set 3 | tabou
# Processing Record 34 of Set 3 | victoria
# Processing Record 35 of Set 3 | zhanaozen
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | ouallam
# Processing Record 38 of Set 3 | la ronge
# Processing Record 39 of Set 3 | kuybysheve
# Processing Record 40 of Set 3 | ribeira grande
# Processing Record 41 of Set 3 | paciran
# Processing Record 42 of Set 3 | mandera
# Processing Record 43 of Set 3 | urengoy
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | cabedelo
# Processing Record 46 of Set 3 | riyadh
# Processing Record 47 of Set 3 | russell
# Processing Record 48 of Set 3 | bilibino
# Processing Record 49 of Set 3 | flinders
# Processing Record 50 of Set 3 | assiniboia
# Processing Record 1 of Set 4 | yuryevets
# Processing Record 2 of Set 4 | preobrazheniye
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 4 | sola
# Processing Record 7 of Set 4 | manzil salim
# Processing Record 8 of Set 4 | carnarvon
# Processing Record 9 of Set 4 | sobolevo
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | george town
# Processing Record 12 of Set 4 | presque isle
# Processing Record 13 of Set 4 | zhongxing
# Processing Record 14 of Set 4 | salvador
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | akoupe
# Processing Record 19 of Set 4 | klaksvik
# Processing Record 20 of Set 4 | labuhan
# Processing Record 21 of Set 4 | vershino-shakhtaminskiy
# Processing Record 22 of Set 4 | paamiut
# Processing Record 23 of Set 4 | mumford
# Processing Record 24 of Set 4 | madimba
# Processing Record 25 of Set 4 | batagay-alyta
# Processing Record 26 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | valley
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 4 | roswell
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | babu
# Processing Record 37 of Set 4 | vestmannaeyjar
# Processing Record 38 of Set 4 | artvin
# Processing Record 39 of Set 4 | santa cruz
# Processing Record 40 of Set 4 | barrow
# Processing Record 41 of Set 4 | tynda
# Processing Record 42 of Set 4 | khatanga
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | nizhnyaya tavda
# Processing Record 45 of Set 4 | atbasar
# Processing Record 46 of Set 4 | college
# Processing Record 47 of Set 4 | istmina
# Processing Record 48 of Set 4 | pahrump
# Processing Record 49 of Set 4 | igrim
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | port elizabeth
# Processing Record 3 of Set 5 | shimoda
# Processing Record 4 of Set 5 | sur
# Processing Record 5 of Set 5 | ibaiti
# Processing Record 6 of Set 5 | pitanga
# Processing Record 7 of Set 5 | odweyne
# Processing Record 8 of Set 5 | kapaa
# Processing Record 9 of Set 5 | alice springs
# Processing Record 10 of Set 5 | soavinandriana
# Processing Record 11 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 5 | morehead
# Processing Record 14 of Set 5 | yerbogachen
# Processing Record 15 of Set 5 | khasan
# Processing Record 16 of Set 5 | kaeo
# Processing Record 17 of Set 5 | vieux-habitants
# Processing Record 18 of Set 5 | lompoc
# Processing Record 19 of Set 5 | champerico
# Processing Record 20 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 5 | luwuk
# Processing Record 22 of Set 5 | mayumba
# Processing Record 23 of Set 5 | goma
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | aykhal
# Processing Record 26 of Set 5 | necochea
# Processing Record 27 of Set 5 | port-cartier
# Processing Record 28 of Set 5 | arkhangelsk
# Processing Record 29 of Set 5 | gat
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | provideniya
# Processing Record 33 of Set 5 | sijunjung
# Processing Record 34 of Set 5 | palmer
# Processing Record 35 of Set 5 | pangody
# Processing Record 36 of Set 5 | hearst
# Processing Record 37 of Set 5 | tiksi
# Processing Record 38 of Set 5 | tura
# Processing Record 39 of Set 5 | raudeberg
# Processing Record 40 of Set 5 | suntar
# Processing Record 41 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 5 | barabinsk
# Processing Record 43 of Set 5 | roald
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | aktau
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | suez
# Processing Record 48 of Set 5 | sopot
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | bud
# Processing Record 4 of Set 6 | tucuman
# Processing Record 5 of Set 6 | inhapim
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | bambous virieux
# Processing Record 8 of Set 6 | andrews
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | kruszwica
# Processing Record 11 of Set 6 | tanout
# Processing Record 12 of Set 6 | puerto lopez
# Processing Record 13 of Set 6 | kinshasa
# Processing Record 14 of Set 6 | nezhinka
# Processing Record 15 of Set 6 | ayan
# Processing Record 16 of Set 6 | hailey
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | norman wells
# Processing Record 19 of Set 6 | srednekolymsk
# Processing Record 20 of Set 6 | mongoumba
# Processing Record 21 of Set 6 | el badari
# City not found. Skipping...
# Processing Record 22 of Set 6 | kingman
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | tianpeng
# Processing Record 25 of Set 6 | socorro
# Processing Record 26 of Set 6 | goderich
# Processing Record 27 of Set 6 | batetskiy
# Processing Record 28 of Set 6 | adrar
# Processing Record 29 of Set 6 | pulsano
# Processing Record 30 of Set 6 | red bluff
# Processing Record 31 of Set 6 | hasaki
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | nizhniy odes
# Processing Record 34 of Set 6 | half moon bay
# Processing Record 35 of Set 6 | leshukonskoye
# Processing Record 36 of Set 6 | lorengau
# Processing Record 37 of Set 6 | shelton
# Processing Record 38 of Set 6 | kadrina
# Processing Record 39 of Set 6 | agirish
# Processing Record 40 of Set 6 | vinh
# Processing Record 41 of Set 6 | pacific grove
# Processing Record 42 of Set 6 | sao filipe
# Processing Record 43 of Set 6 | kalianget
# Processing Record 44 of Set 6 | westport
# Processing Record 45 of Set 6 | punta alta
# Processing Record 46 of Set 6 | faanui
# Processing Record 47 of Set 6 | araouane
# Processing Record 48 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 49 of Set 6 | kamenka
# Processing Record 50 of Set 6 | zhigansk
# Processing Record 1 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 7 | atalanti
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | saint-georges
# Processing Record 5 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 6 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 7 of Set 7 | varzea grande
# Processing Record 8 of Set 7 | zeya
# Processing Record 9 of Set 7 | makamba
# Processing Record 10 of Set 7 | negombo
# Processing Record 11 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 12 of Set 7 | talnakh
# Processing Record 13 of Set 7 | tortosa
# Processing Record 14 of Set 7 | santo antonio do sudoeste
# Processing Record 15 of Set 7 | shu
# Processing Record 16 of Set 7 | tukrah
# Processing Record 17 of Set 7 | kon tum
# Processing Record 18 of Set 7 | kapoeta
# Processing Record 19 of Set 7 | rayachoti
# Processing Record 20 of Set 7 | salisbury
# Processing Record 21 of Set 7 | hualmay
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | rongcheng
# Processing Record 24 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 25 of Set 7 | ostrovnoy
# Processing Record 26 of Set 7 | zapolyarnyy
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | keti bandar
# Processing Record 29 of Set 7 | kamogawa
# Processing Record 30 of Set 7 | homer
# Processing Record 31 of Set 7 | kampot
# Processing Record 32 of Set 7 | willowmore
# Processing Record 33 of Set 7 | marienburg
# Processing Record 34 of Set 7 | belyy yar
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | turukhansk
# Processing Record 39 of Set 7 | chingirlau
# Processing Record 40 of Set 7 | bulancak
# Processing Record 41 of Set 7 | shache
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | barinas
# Processing Record 44 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 7 | saint-denis
# Processing Record 46 of Set 7 | ingham
# Processing Record 47 of Set 7 | sabang
# Processing Record 48 of Set 7 | atambua
# Processing Record 49 of Set 7 | nanga eboko
# Processing Record 50 of Set 7 | dracena
# Processing Record 1 of Set 8 | kytmanovo
# Processing Record 2 of Set 8 | varnavino
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | bilma
# Processing Record 5 of Set 8 | abu samrah
# Processing Record 6 of Set 8 | nouadhibou
# Processing Record 7 of Set 8 | sangar
# Processing Record 8 of Set 8 | san juan
# Processing Record 9 of Set 8 | elko
# Processing Record 10 of Set 8 | maragogi
# Processing Record 11 of Set 8 | kununurra
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | carcassonne
# Processing Record 14 of Set 8 | chara
# Processing Record 15 of Set 8 | moerai
# Processing Record 16 of Set 8 | kourou
# Processing Record 17 of Set 8 | jennings
# Processing Record 18 of Set 8 | pisco
# Processing Record 19 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 8 | gazanjyk
# Processing Record 21 of Set 8 | hammerfest
# Processing Record 22 of Set 8 | vila velha
# Processing Record 23 of Set 8 | luderitz
# Processing Record 24 of Set 8 | mandurah
# Processing Record 25 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 8 | clinton
# Processing Record 27 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 28 of Set 8 | kyaikto
# Processing Record 29 of Set 8 | hirara
# Processing Record 30 of Set 8 | tsabong
# Processing Record 31 of Set 8 | karabulak
# Processing Record 32 of Set 8 | skjervoy
# Processing Record 33 of Set 8 | san patricio
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | camacha
# Processing Record 36 of Set 8 | fare
# Processing Record 37 of Set 8 | koslan
# Processing Record 38 of Set 8 | san policarpo
# Processing Record 39 of Set 8 | quatre cocos
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | chitral
# Processing Record 43 of Set 8 | ambilobe
# Processing Record 44 of Set 8 | kommunisticheskiy
# Processing Record 45 of Set 8 | egvekinot
# Processing Record 46 of Set 8 | voznesenskoye
# Processing Record 47 of Set 8 | lagoa
# Processing Record 48 of Set 8 | havre-saint-pierre
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | salalah
# Processing Record 2 of Set 9 | pathein
# Processing Record 3 of Set 9 | banda aceh
# Processing Record 4 of Set 9 | burica
# City not found. Skipping...
# Processing Record 5 of Set 9 | fukue
# Processing Record 6 of Set 9 | mariinsk
# Processing Record 7 of Set 9 | kitimat
# Processing Record 8 of Set 9 | dickinson
# Processing Record 9 of Set 9 | seoul
# Processing Record 10 of Set 9 | constitucion
# Processing Record 11 of Set 9 | inta
# Processing Record 12 of Set 9 | krasnyy chikoy
# Processing Record 13 of Set 9 | rancho palos verdes
# Processing Record 14 of Set 9 | jawhar
# Processing Record 15 of Set 9 | aras
# Processing Record 16 of Set 9 | volginskiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | scarborough
# Processing Record 18 of Set 9 | pochutla
# Processing Record 19 of Set 9 | udayagiri
# Processing Record 20 of Set 9 | novosineglazovskiy
# Processing Record 21 of Set 9 | staryy biser
# City not found. Skipping...
# Processing Record 22 of Set 9 | grindavik
# Processing Record 23 of Set 9 | soto la marina
# Processing Record 24 of Set 9 | amapa
# Processing Record 25 of Set 9 | phan thiet
# Processing Record 26 of Set 9 | antalaha
# Processing Record 27 of Set 9 | praia da vitoria
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | katherine
# Processing Record 30 of Set 9 | labytnangi
# Processing Record 31 of Set 9 | adre
# Processing Record 32 of Set 9 | congonhas
# Processing Record 33 of Set 9 | marystown
# Processing Record 34 of Set 9 | san luis
# Processing Record 35 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 9 | ontario
# Processing Record 37 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 9 | baruun-urt
# Processing Record 39 of Set 9 | tual
# Processing Record 40 of Set 9 | barre
# Processing Record 41 of Set 9 | padang
# Processing Record 42 of Set 9 | hun
# Processing Record 43 of Set 9 | shubarshi
# Processing Record 44 of Set 9 | cusset
# Processing Record 45 of Set 9 | porto novo
# Processing Record 46 of Set 9 | yumen
# Processing Record 47 of Set 9 | mareeba
# Processing Record 48 of Set 9 | karcag
# Processing Record 49 of Set 9 | kirakira
# Processing Record 50 of Set 9 | lavumisa
# Processing Record 1 of Set 10 | kibiti
# Processing Record 2 of Set 10 | sechura
# Processing Record 3 of Set 10 | ocampo
# Processing Record 4 of Set 10 | aligudarz
# Processing Record 5 of Set 10 | billings
# Processing Record 6 of Set 10 | waipawa
# Processing Record 7 of Set 10 | ukiah
# Processing Record 8 of Set 10 | chongwe
# Processing Record 9 of Set 10 | katobu
# Processing Record 10 of Set 10 | sindor
# Processing Record 11 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 10 | kholmogory
# Processing Record 13 of Set 10 | los algarrobos
# Processing Record 14 of Set 10 | banita
# Processing Record 15 of Set 10 | byron bay
# Processing Record 16 of Set 10 | baiao
# Processing Record 17 of Set 10 | gharo
# Processing Record 18 of Set 10 | nortelandia
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | hami
# Processing Record 21 of Set 10 | tezu
# Processing Record 22 of Set 10 | oranjemund
# Processing Record 23 of Set 10 | bouna
# Processing Record 24 of Set 10 | peleduy
# Processing Record 25 of Set 10 | coro
# Processing Record 26 of Set 10 | timra
# Processing Record 27 of Set 10 | camacupa
# Processing Record 28 of Set 10 | mahajanga
# Processing Record 29 of Set 10 | kendari
# Processing Record 30 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 10 | buluang
# Processing Record 32 of Set 10 | katsuura
# Processing Record 33 of Set 10 | jalingo
# Processing Record 34 of Set 10 | soyo
# Processing Record 35 of Set 10 | damaturu
# Processing Record 36 of Set 10 | susuman
# Processing Record 37 of Set 10 | ucluelet
# Processing Record 38 of Set 10 | port lincoln
# Processing Record 39 of Set 10 | marzuq
# Processing Record 40 of Set 10 | arkadelphia
# Processing Record 41 of Set 10 | imeni poliny osipenko
# Processing Record 42 of Set 10 | georgetown
# Processing Record 43 of Set 10 | ekangala
# Processing Record 44 of Set 10 | marsh harbour
# Processing Record 45 of Set 10 | karema
# Processing Record 46 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 10 | chiredzi
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | gizo
# Processing Record 50 of Set 10 | newport
# Processing Record 1 of Set 11 | neunkirchen
# Processing Record 2 of Set 11 | port augusta
# Processing Record 3 of Set 11 | machiques
# Processing Record 4 of Set 11 | port hawkesbury
# Processing Record 5 of Set 11 | nuuk
# Processing Record 6 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 7 of Set 11 | lata
# Processing Record 8 of Set 11 | wanning
# Processing Record 9 of Set 11 | luan
# Processing Record 10 of Set 11 | cabo san lucas
# Processing Record 11 of Set 11 | jambi
# Processing Record 12 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 11 | praia
# Processing Record 14 of Set 11 | ginir
# Processing Record 15 of Set 11 | varnamo
# Processing Record 16 of Set 11 | new port richey
# Processing Record 17 of Set 11 | phalaborwa
# Processing Record 18 of Set 11 | morant bay
# Processing Record 19 of Set 11 | salinopolis
# Processing Record 20 of Set 11 | merrill
# Processing Record 21 of Set 11 | deputatskiy
# Processing Record 22 of Set 11 | bridlington
# Processing Record 23 of Set 11 | pangkalanbuun
# Processing Record 24 of Set 11 | dunedin
# Processing Record 25 of Set 11 | chapaevsk
# Processing Record 26 of Set 11 | goundam
# Processing Record 27 of Set 11 | abu dhabi
# Processing Record 28 of Set 11 | akdepe
# Processing Record 29 of Set 11 | semikarakorsk
# Processing Record 30 of Set 11 | kolyvan
# Processing Record 31 of Set 11 | barsovo
# Processing Record 32 of Set 11 | tucumcari
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | turiacu
# Processing Record 35 of Set 11 | rantepao
# Processing Record 36 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 11 | vila praia de ancora
# Processing Record 38 of Set 11 | sterling
# Processing Record 39 of Set 11 | salamiyah
# Processing Record 40 of Set 11 | zainsk
# Processing Record 41 of Set 11 | campbellsville
# Processing Record 42 of Set 11 | tarata
# Processing Record 43 of Set 11 | ilhabela
# Processing Record 44 of Set 11 | whitehorse
# Processing Record 45 of Set 11 | macapa
# Processing Record 46 of Set 11 | bodaybo
# Processing Record 47 of Set 11 | sarh
# Processing Record 48 of Set 11 | cloppenburg
# Processing Record 49 of Set 11 | penzance
# Processing Record 50 of Set 11 | fuxin
# Processing Record 1 of Set 12 | san buenaventura
# Processing Record 2 of Set 12 | kedrovyy
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | batemans bay
# Processing Record 5 of Set 12 | catamarca
# Processing Record 6 of Set 12 | lucapa
# Processing Record 7 of Set 12 | makinsk
# Processing Record 8 of Set 12 | iwata
# Processing Record 9 of Set 12 | tommot
# Processing Record 10 of Set 12 | mardin
# Processing Record 11 of Set 12 | ler
# Processing Record 12 of Set 12 | choya
# Processing Record 13 of Set 12 | oktyabrskoye
# Processing Record 14 of Set 12 | madras
# Processing Record 15 of Set 12 | toguchin
# Processing Record 16 of Set 12 | key west
# Processing Record 17 of Set 12 | mahebourg
# Processing Record 18 of Set 12 | inuvik
# Processing Record 19 of Set 12 | morro da fumaca
# Processing Record 20 of Set 12 | aranda de duero
# Processing Record 21 of Set 12 | hambantota
# Processing Record 22 of Set 12 | griffith
# Processing Record 23 of Set 12 | turcianske teplice
# Processing Record 24 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 12 | imst
# Processing Record 26 of Set 12 | raga
# Processing Record 27 of Set 12 | richards bay
# Processing Record 28 of Set 12 | pareora
# Processing Record 29 of Set 12 | wanaka
# Processing Record 30 of Set 12 | buraydah
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | porto franco
# Processing Record 33 of Set 12 | kegalla
# City not found. Skipping...
# Processing Record 34 of Set 12 | san-pedro
# Processing Record 35 of Set 12 | tessalit
# Processing Record 36 of Set 12 | sistranda
# Processing Record 37 of Set 12 | el fuerte
# Processing Record 38 of Set 12 | qasigiannguit
# Processing Record 39 of Set 12 | belaya gora
# Processing Record 40 of Set 12 | noumea
# Processing Record 41 of Set 12 | vao
# Processing Record 42 of Set 12 | foam lake
# Processing Record 43 of Set 12 | lagunas
# Processing Record 44 of Set 12 | leiyang
# Processing Record 45 of Set 12 | te horo
# Processing Record 46 of Set 12 | hornepayne
# Processing Record 47 of Set 12 | strezhevoy
# Processing Record 48 of Set 12 | severobaykalsk
# Processing Record 49 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 50 of Set 12 | fagernes
# Processing Record 1 of Set 13 | harper
# Processing Record 2 of Set 13 | ust-maya
# Processing Record 3 of Set 13 | aranos
# Processing Record 4 of Set 13 | nakusp
# Processing Record 5 of Set 13 | itarema
# Processing Record 6 of Set 13 | mutis
# Processing Record 7 of Set 13 | mwinilunga
# Processing Record 8 of Set 13 | esperance
# Processing Record 9 of Set 13 | novo aripuana
# Processing Record 10 of Set 13 | elk
# Processing Record 11 of Set 13 | murray bridge
# Processing Record 12 of Set 13 | kasongo-lunda
# Processing Record 13 of Set 13 | lianran
# Processing Record 14 of Set 13 | itupiranga
# Processing Record 15 of Set 13 | montana
# Processing Record 16 of Set 13 | kupang
# Processing Record 17 of Set 13 | cabadiangan
# Processing Record 18 of Set 13 | mackay
# Processing Record 19 of Set 13 | tokat
# Processing Record 20 of Set 13 | yacuiba
# Processing Record 21 of Set 13 | selenice
# Processing Record 22 of Set 13 | dwarka
# Processing Record 23 of Set 13 | haapiti
# Processing Record 24 of Set 13 | calafell
# Processing Record 25 of Set 13 | ponta delgada
# Processing Record 26 of Set 13 | kapustin yar
# Processing Record 27 of Set 13 | smidovich
# Processing Record 28 of Set 13 | sorong
# Processing Record 29 of Set 13 | diofior
# Processing Record 30 of Set 13 | mana
# Processing Record 31 of Set 13 | buckingham
# Processing Record 32 of Set 13 | luanda
# Processing Record 33 of Set 13 | omboue
# Processing Record 34 of Set 13 | nanaimo
# Processing Record 35 of Set 13 | santa rita
# Processing Record 36 of Set 13 | davila
# Processing Record 37 of Set 13 | panzhihua
# Processing Record 38 of Set 13 | taitung
# Processing Record 39 of Set 13 | abha
# Processing Record 40 of Set 13 | caravelas
# Processing Record 41 of Set 13 | berlevag
# Processing Record 42 of Set 13 | mpulungu
# Processing Record 43 of Set 13 | santo domingo
# Processing Record 44 of Set 13 | nhulunbuy
# Processing Record 45 of Set 13 | maturin
# Processing Record 46 of Set 13 | san carlos de bariloche
# Processing Record 47 of Set 13 | bathsheba
# Processing Record 48 of Set 13 | bourges
# Processing Record 49 of Set 13 | pietersburg
# Processing Record 50 of Set 13 | boo
# Processing Record 1 of Set 14 | saint-pierre
# Processing Record 2 of Set 14 | bekovo
# Processing Record 3 of Set 14 | abnub
# Processing Record 4 of Set 14 | mulege
# Processing Record 5 of Set 14 | mixtequilla
# City not found. Skipping...
# Processing Record 6 of Set 14 | kenitra
# Processing Record 7 of Set 14 | tornio
# Processing Record 8 of Set 14 | gateshead
# Processing Record 9 of Set 14 | tagusao
# Processing Record 10 of Set 14 | ecoporanga
# Processing Record 11 of Set 14 | vaitape
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | palana
# Processing Record 14 of Set 14 | carroll
# Processing Record 15 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 14 | reforma
# Processing Record 17 of Set 14 | batesville
# Processing Record 18 of Set 14 | chicama
# Processing Record 19 of Set 14 | henties bay
# Processing Record 20 of Set 14 | ambunti
# Processing Record 21 of Set 14 | calama
# Processing Record 22 of Set 14 | reporoa
# Processing Record 23 of Set 14 | hvide sande
# Processing Record 24 of Set 14 | bonavista
# Processing Record 25 of Set 14 | marsabit
# Processing Record 26 of Set 14 | broken hill
# Processing Record 27 of Set 14 | annau
# Processing Record 28 of Set 14 | waingapu
# Processing Record 29 of Set 14 | atarra
# Processing Record 30 of Set 14 | acajutla
# Processing Record 31 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 32 of Set 14 | murakami
# Processing Record 33 of Set 14 | torring
# Processing Record 34 of Set 14 | carsamba
# Processing Record 35 of Set 14 | beloha
# Processing Record 36 of Set 14 | lira
# Processing Record 37 of Set 14 | grand forks
# Processing Record 38 of Set 14 | narimanov
# Processing Record 39 of Set 14 | vershino-darasunskiy
# Processing Record 40 of Set 14 | pandan
# Processing Record 41 of Set 14 | walvis bay
# Processing Record 42 of Set 14 | zyryanka
# Processing Record 43 of Set 14 | jackson
# Processing Record 44 of Set 14 | luba
# Processing Record 45 of Set 14 | savannah bight
# Processing Record 46 of Set 14 | harbour breton
# Processing Record 47 of Set 14 | basco
# Processing Record 48 of Set 14 | partizanskoye
# Processing Record 49 of Set 14 | bandarbeyla
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | altus
# Processing Record 2 of Set 15 | paracale
# Processing Record 3 of Set 15 | lima
# Processing Record 4 of Set 15 | itoman
# Processing Record 5 of Set 15 | morristown
# Processing Record 6 of Set 15 | astoria
# Processing Record 7 of Set 15 | marawi
# Processing Record 8 of Set 15 | the valley
# Processing Record 9 of Set 15 | yurino
# Processing Record 10 of Set 15 | oranjestad
# Processing Record 11 of Set 15 | bad neustadt
# City not found. Skipping...
# Processing Record 12 of Set 15 | eureka
# Processing Record 13 of Set 15 | guaruja
# Processing Record 14 of Set 15 | ano mera
# Processing Record 15 of Set 15 | storm lake
# Processing Record 16 of Set 15 | garissa
# Processing Record 17 of Set 15 | santa cruz de tenerife
# Processing Record 18 of Set 15 | bethalto
# Processing Record 19 of Set 15 | gladstone
# Processing Record 20 of Set 15 | iskateley
# Processing Record 21 of Set 15 | borogontsy
# Processing Record 22 of Set 15 | tomter
# Processing Record 23 of Set 15 | shieli
# Processing Record 24 of Set 15 | guaratinga
# Processing Record 25 of Set 15 | port hedland
# Processing Record 26 of Set 15 | hays
# Processing Record 27 of Set 15 | ochsenfurt
# Processing Record 28 of Set 15 | churapcha
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | matay
# Processing Record 31 of Set 15 | brownsville
# Processing Record 32 of Set 15 | vanavara
# Processing Record 33 of Set 15 | cam ranh
# Processing Record 34 of Set 15 | galle
# Processing Record 35 of Set 15 | makakilo city
# Processing Record 36 of Set 15 | lingyuan
# Processing Record 37 of Set 15 | male
# Processing Record 38 of Set 15 | salym
# Processing Record 39 of Set 15 | chifeng
# Processing Record 40 of Set 15 | healdsburg
# Processing Record 41 of Set 15 | prescott
# Processing Record 42 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 43 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 44 of Set 15 | pauleni-ciuc
# Processing Record 45 of Set 15 | juba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Moss Point      US  30.4116  -88.5345     76.44        68          40
# 1         Ahipara      NZ -35.1667  173.1667     62.17        79          90
# 2       Karpathos      GR  35.5070   27.2132     58.96        72         100
# 3      Portlethen      GB  57.0547   -2.1307     39.78        79         100
# 4         Batagay      RU  67.6333  134.6333    -35.27        98         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 684       Chifeng      CN  42.2683  118.9636     25.48        62           0
# 685    Healdsburg      US  38.6105 -122.8692     68.54        57          20
# 686      Prescott      US  34.5400 -112.4685     53.91        21           1
# 687  Pauleni-Ciuc      RO  46.4000   25.8333     29.88        86           2
# 688          Juba      SS   4.8517   31.5825     85.53        30          96
#
#      Wind Speed Current Description
# 0          5.75    scattered clouds
# 1          3.60     overcast clouds
# 2          8.05     overcast clouds
# 3         10.36          light rain
# 4          2.57     overcast clouds
# ..          ...                 ...
# 684        5.50           clear sky
# 685        0.00          few clouds
# 686        8.01           clear sky
# 687        2.08           clear sky
# 688        2.19     overcast clouds
#
# [689 rows x 9 columns]

# %%
#Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
