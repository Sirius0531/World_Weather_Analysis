# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\sliao\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\sliao\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
# Import the time library and the datetime module from the datetime library 
import time

# %%
from citipy import citipy
from datetime import datetime

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# Add the latitudes and longitudes to a list.
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
lat_lngs

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# # Create an endpoint URL for a city.
# city_url = url + "&q=" + "Boston"
# weather_response=requests.get(city_url)
# weather_json=weather_response.json()
# weather_json.keys()

# %%
# weather_json.get("main")
# weather_json

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 36.23,
#   'feels_like': 31.28,
#   'temp_min': 30.04,
#   'temp_max': 39.97,
#   'pressure': 1023,
#   'humidity': 37},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 342, 'gust': 18.01},
#  'clouds': {'all': 20},
#  'dt': 1637796011,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1637754384,
#   'sunset': 1637788561},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 39.97 37 20 5.99

# %%
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-11-24 23:20:11'

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
  

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")
  

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cockburn town
# Processing Record 2 of Set 1 | teahupoo
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | coquimbo
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | bolungarvik
# Processing Record 17 of Set 1 | watsa
# Processing Record 18 of Set 1 | saint-francois
# Processing Record 19 of Set 1 | nizhneyansk
# Processing Record 20 of Set 1 | taolanaro
# Processing Record 21 of Set 1 | matara
# Processing Record 22 of Set 1 | illoqqortoormiut
# Processing Record 23 of Set 1 | pontianak
# Processing Record 24 of Set 1 | king city
# Processing Record 25 of Set 1 | namie
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | haines junction
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | santa marta
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | adwa
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | san carlos de bariloche
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | warqla
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | tornio
# Processing Record 46 of Set 1 | pangai
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | bushtyno
# Processing Record 50 of Set 1 | port moresby
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | salalah
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | coos bay
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | ahuimanu
# Processing Record 12 of Set 2 | basco
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | guadalupe y calvo
# Processing Record 15 of Set 2 | waipawa
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | sendai
# Processing Record 18 of Set 2 | bambanglipuro
# Processing Record 19 of Set 2 | mount isa
# Processing Record 20 of Set 2 | babanusah
# Processing Record 21 of Set 2 | port augusta
# Processing Record 22 of Set 2 | marienburg
# Processing Record 23 of Set 2 | gigmoto
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | batemans bay
# Processing Record 27 of Set 2 | sur
# Processing Record 28 of Set 2 | north bend
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | labutta
# Processing Record 32 of Set 2 | nhulunbuy
# Processing Record 33 of Set 2 | hamilton
# Processing Record 34 of Set 2 | jacqueville
# Processing Record 35 of Set 2 | sumbawa
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | tilichiki
# Processing Record 38 of Set 2 | karakendzha
# Processing Record 39 of Set 2 | punta cardon
# Processing Record 40 of Set 2 | tsihombe
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | barentsburg
# Processing Record 43 of Set 2 | borogontsy
# Processing Record 44 of Set 2 | mahajanga
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | pouembout
# Processing Record 48 of Set 2 | soyo
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | lorengau
# Processing Record 1 of Set 3 | viligili
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | puerto escondido
# Processing Record 5 of Set 3 | san cristobal
# Processing Record 6 of Set 3 | isiro
# Processing Record 7 of Set 3 | kilindoni
# Processing Record 8 of Set 3 | kavieng
# Processing Record 9 of Set 3 | skibbereen
# Processing Record 10 of Set 3 | camacha
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | zmievka
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | mutoko
# Processing Record 15 of Set 3 | rheinau
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | dalbandin
# Processing Record 18 of Set 3 | ancud
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | paamiut
# Processing Record 21 of Set 3 | halifax
# Processing Record 22 of Set 3 | samarinda
# Processing Record 23 of Set 3 | vladyslavivka
# Processing Record 24 of Set 3 | tabiauea
# Processing Record 25 of Set 3 | nefteyugansk
# Processing Record 26 of Set 3 | talnakh
# Processing Record 27 of Set 3 | eskilstuna
# Processing Record 28 of Set 3 | husavik
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | tungor
# Processing Record 31 of Set 3 | den helder
# Processing Record 32 of Set 3 | pineville
# Processing Record 33 of Set 3 | swan hill
# Processing Record 34 of Set 3 | meulaboh
# Processing Record 35 of Set 3 | kouroussa
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | nouadhibou
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | petrovsk-zabaykalskiy
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | namatanai
# Processing Record 42 of Set 3 | takoradi
# Processing Record 43 of Set 3 | buluang
# Processing Record 44 of Set 3 | beringovskiy
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | cognac
# Processing Record 47 of Set 3 | huarmey
# Processing Record 48 of Set 3 | umzimvubu
# Processing Record 49 of Set 3 | tres arroyos
# Processing Record 50 of Set 3 | vila
# Processing Record 1 of Set 4 | rio gallegos
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | sirohi
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | vao
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | tommot
# Processing Record 8 of Set 4 | belushya guba
# Processing Record 9 of Set 4 | porto velho
# Processing Record 10 of Set 4 | talaya
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | attawapiskat
# Processing Record 13 of Set 4 | katima mulilo
# Processing Record 14 of Set 4 | lubango
# Processing Record 15 of Set 4 | inhambupe
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | saint-denis
# Processing Record 19 of Set 4 | samalaeulu
# Processing Record 20 of Set 4 | mayo
# Processing Record 21 of Set 4 | bay roberts
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | portree
# Processing Record 24 of Set 4 | cape town
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | da nang
# Processing Record 27 of Set 4 | itoman
# Processing Record 28 of Set 4 | taltal
# Processing Record 29 of Set 4 | xiongyue
# Processing Record 30 of Set 4 | phuket
# Processing Record 31 of Set 4 | matagami
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | lanzhou
# Processing Record 34 of Set 4 | itarema
# Processing Record 35 of Set 4 | campoverde
# Processing Record 36 of Set 4 | vysokogornyy
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | bordei verde
# Processing Record 40 of Set 4 | sentyabrskiy
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | grand river south east
# Processing Record 43 of Set 4 | tarudant
# Processing Record 44 of Set 4 | manokwari
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | kawalu
# Processing Record 47 of Set 4 | pevek
# Processing Record 48 of Set 4 | ternate
# Processing Record 49 of Set 4 | manavalakurichi
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | avallon
# Processing Record 2 of Set 5 | thompson
# Processing Record 3 of Set 5 | anderson
# Processing Record 4 of Set 5 | mandalgovi
# Processing Record 5 of Set 5 | kamenka
# Processing Record 6 of Set 5 | wulanhaote
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | lakeside
# Processing Record 9 of Set 5 | narsaq
# Processing Record 10 of Set 5 | batagay-alyta
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | alyangula
# Processing Record 14 of Set 5 | mutis
# Processing Record 15 of Set 5 | bukachacha
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | ribas do rio pardo
# Processing Record 18 of Set 5 | finschhafen
# Processing Record 19 of Set 5 | komsomolskiy
# Processing Record 20 of Set 5 | yar-sale
# Processing Record 21 of Set 5 | pangkalanbuun
# Processing Record 22 of Set 5 | jiwani
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | dzhusaly
# Processing Record 25 of Set 5 | barrow
# Processing Record 26 of Set 5 | bengkulu
# Processing Record 27 of Set 5 | necochea
# Processing Record 28 of Set 5 | magdagachi
# Processing Record 29 of Set 5 | eskisehir
# Processing Record 30 of Set 5 | yerbogachen
# Processing Record 31 of Set 5 | urengoy
# Processing Record 32 of Set 5 | riyadh
# Processing Record 33 of Set 5 | kuche
# Processing Record 34 of Set 5 | lazaro cardenas
# Processing Record 35 of Set 5 | fanai
# Processing Record 36 of Set 5 | marcona
# Processing Record 37 of Set 5 | dongsheng
# Processing Record 38 of Set 5 | vanimo
# Processing Record 39 of Set 5 | scarborough
# Processing Record 40 of Set 5 | vestmanna
# Processing Record 41 of Set 5 | kandrian
# Processing Record 42 of Set 5 | tuatapere
# Processing Record 43 of Set 5 | sompeta
# Processing Record 44 of Set 5 | kaitangata
# Processing Record 45 of Set 5 | kapaa
# Processing Record 46 of Set 5 | mar del plata
# Processing Record 47 of Set 5 | sterling
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | misratah
# Processing Record 50 of Set 5 | winneba
# Processing Record 1 of Set 6 | saleaula
# Processing Record 2 of Set 6 | naryan-mar
# Processing Record 3 of Set 6 | sakakah
# Processing Record 4 of Set 6 | lhokseumawe
# Processing Record 5 of Set 6 | hirara
# Processing Record 6 of Set 6 | port lincoln
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | zaysan
# Processing Record 9 of Set 6 | along
# Processing Record 10 of Set 6 | baykit
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | shangzhi
# Processing Record 14 of Set 6 | lagos
# Processing Record 15 of Set 6 | freeport
# Processing Record 16 of Set 6 | chagda
# Processing Record 17 of Set 6 | ouesso
# Processing Record 18 of Set 6 | mecca
# Processing Record 19 of Set 6 | ribeira grande
# Processing Record 20 of Set 6 | cidreira
# Processing Record 21 of Set 6 | havelock
# Processing Record 22 of Set 6 | ketchikan
# Processing Record 23 of Set 6 | trairi
# Processing Record 24 of Set 6 | springdale
# Processing Record 25 of Set 6 | iranshahr
# Processing Record 26 of Set 6 | altay
# Processing Record 27 of Set 6 | margate
# Processing Record 28 of Set 6 | bud
# Processing Record 29 of Set 6 | guerrero negro
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | vestbygda
# Processing Record 32 of Set 6 | westport
# Processing Record 33 of Set 6 | baruun-urt
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | barcelona
# Processing Record 36 of Set 6 | puerto colombia
# Processing Record 37 of Set 6 | blagoveshchenka
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | ituango
# Processing Record 41 of Set 6 | kochki
# Processing Record 42 of Set 6 | marianske lazne
# Processing Record 43 of Set 6 | bilma
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | kivertsi
# Processing Record 46 of Set 6 | aklavik
# Processing Record 47 of Set 6 | mishan
# Processing Record 48 of Set 6 | talcahuano
# Processing Record 49 of Set 6 | wynyard
# Processing Record 50 of Set 6 | camana
# Processing Record 1 of Set 7 | chamrajnagar
# Processing Record 2 of Set 7 | murray bridge
# Processing Record 3 of Set 7 | jos
# Processing Record 4 of Set 7 | witrivier
# Processing Record 5 of Set 7 | jalu
# Processing Record 6 of Set 7 | leningradskiy
# Processing Record 7 of Set 7 | makungu
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | kenitra
# Processing Record 10 of Set 7 | polson
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | staryy nadym
# Processing Record 13 of Set 7 | koslan
# Processing Record 14 of Set 7 | mahanje
# Processing Record 15 of Set 7 | kavaratti
# Processing Record 16 of Set 7 | shieli
# Processing Record 17 of Set 7 | sabya
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | fowa
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | wahlstedt
# Processing Record 22 of Set 7 | abu kamal
# Processing Record 23 of Set 7 | marawi
# Processing Record 24 of Set 7 | najran
# Processing Record 25 of Set 7 | ukiah
# Processing Record 26 of Set 7 | padang
# Processing Record 27 of Set 7 | tabou
# Processing Record 28 of Set 7 | huanan
# Processing Record 29 of Set 7 | tatawin
# Processing Record 30 of Set 7 | matir
# Processing Record 31 of Set 7 | nynashamn
# Processing Record 32 of Set 7 | gurskoye
# Processing Record 33 of Set 7 | kpandu
# Processing Record 34 of Set 7 | kristinehamn
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | odweyne
# Processing Record 37 of Set 7 | marzuq
# Processing Record 38 of Set 7 | mehamn
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | anloga
# Processing Record 41 of Set 7 | mount gambier
# Processing Record 42 of Set 7 | kulhudhuffushi
# Processing Record 43 of Set 7 | batticaloa
# Processing Record 44 of Set 7 | porto novo
# Processing Record 45 of Set 7 | noumea
# Processing Record 46 of Set 7 | sioux lookout
# Processing Record 47 of Set 7 | maniitsoq
# Processing Record 48 of Set 7 | jeremie
# Processing Record 49 of Set 7 | umm durman
# Processing Record 50 of Set 7 | nikolsk
# Processing Record 1 of Set 8 | luganville
# Processing Record 2 of Set 8 | esperance
# Processing Record 3 of Set 8 | toliary
# Processing Record 4 of Set 8 | luangwa
# Processing Record 5 of Set 8 | ostersund
# Processing Record 6 of Set 8 | nkayi
# Processing Record 7 of Set 8 | akdepe
# Processing Record 8 of Set 8 | san jeronimo
# Processing Record 9 of Set 8 | carauari
# Processing Record 10 of Set 8 | santa maria del oro
# Processing Record 11 of Set 8 | sungairaya
# Processing Record 12 of Set 8 | ngukurr
# Processing Record 13 of Set 8 | rio bueno
# Processing Record 14 of Set 8 | sao lourenco do sul
# Processing Record 15 of Set 8 | vitim
# Processing Record 16 of Set 8 | bur gabo
# Processing Record 17 of Set 8 | linjiang
# Processing Record 18 of Set 8 | salinopolis
# Processing Record 19 of Set 8 | bolshiye uki
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | salym
# Processing Record 22 of Set 8 | llaillay
# Processing Record 23 of Set 8 | morondava
# Processing Record 24 of Set 8 | okhotsk
# Processing Record 25 of Set 8 | khandbari
# Processing Record 26 of Set 8 | pozo colorado
# Processing Record 27 of Set 8 | hurghada
# Processing Record 28 of Set 8 | yaypan
# Processing Record 29 of Set 8 | grafton
# Processing Record 30 of Set 8 | norman wells
# Processing Record 31 of Set 8 | biltine
# Processing Record 32 of Set 8 | batamshinskiy
# Processing Record 33 of Set 8 | codrington
# Processing Record 34 of Set 8 | garowe
# Processing Record 35 of Set 8 | kodiak
# Processing Record 36 of Set 8 | alice springs
# Processing Record 37 of Set 8 | otta
# Processing Record 38 of Set 8 | bosaso
# Processing Record 39 of Set 8 | revda
# Processing Record 40 of Set 8 | innisfail
# Processing Record 41 of Set 8 | srednekolymsk
# Processing Record 42 of Set 8 | lata
# Processing Record 43 of Set 8 | amderma
# Processing Record 44 of Set 8 | dzitas
# Processing Record 45 of Set 8 | santa maria
# Processing Record 46 of Set 8 | loukhi
# Processing Record 47 of Set 8 | galveston
# Processing Record 48 of Set 8 | la ronge
# Processing Record 49 of Set 8 | bandarbeyla
# Processing Record 50 of Set 8 | kieta
# Processing Record 1 of Set 9 | atambua
# Processing Record 2 of Set 9 | constitucion
# Processing Record 3 of Set 9 | ilulissat
# Processing Record 4 of Set 9 | araouane
# Processing Record 5 of Set 9 | bandundu
# Processing Record 6 of Set 9 | arlit
# Processing Record 7 of Set 9 | kidal
# Processing Record 8 of Set 9 | alakurtti
# Processing Record 9 of Set 9 | isabela
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | mys shmidta
# Processing Record 12 of Set 9 | nuuk
# Processing Record 13 of Set 9 | terrace
# Processing Record 14 of Set 9 | broken arrow
# Processing Record 15 of Set 9 | cayeli
# Processing Record 16 of Set 9 | calama
# Processing Record 17 of Set 9 | colorado springs
# Processing Record 18 of Set 9 | thunder bay
# Processing Record 19 of Set 9 | zhirnovsk
# Processing Record 20 of Set 9 | severnoye
# Processing Record 21 of Set 9 | lalibela
# Processing Record 22 of Set 9 | cervo
# Processing Record 23 of Set 9 | moulmeingyun
# Processing Record 24 of Set 9 | meadow lake
# Processing Record 25 of Set 9 | tromso
# Processing Record 26 of Set 9 | tarrega
# Processing Record 27 of Set 9 | meyungs
# Processing Record 28 of Set 9 | verkhnyaya inta
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | grand centre
# Processing Record 31 of Set 9 | celarevo
# Processing Record 32 of Set 9 | nizwa
# Processing Record 33 of Set 9 | lavrentiya
# Processing Record 34 of Set 9 | sambava
# Processing Record 35 of Set 9 | celestun
# Processing Record 36 of Set 9 | huaihua
# Processing Record 37 of Set 9 | klyuchi
# Processing Record 38 of Set 9 | vaitupu
# Processing Record 39 of Set 9 | litayen
# Processing Record 40 of Set 9 | cayenne
# Processing Record 41 of Set 9 | xuddur
# Processing Record 42 of Set 9 | khorramabad
# Processing Record 43 of Set 9 | berdigestyakh
# Processing Record 44 of Set 9 | vaitape
# Processing Record 45 of Set 9 | chokurdakh
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | san ignacio
# Processing Record 48 of Set 9 | uige
# Processing Record 49 of Set 9 | kralendijk
# Processing Record 50 of Set 9 | gat
# Processing Record 1 of Set 10 | pisco
# Processing Record 2 of Set 10 | cheremukhovo
# Processing Record 3 of Set 10 | naryshkino
# Processing Record 4 of Set 10 | havoysund
# Processing Record 5 of Set 10 | brandon
# Processing Record 6 of Set 10 | cap malheureux
# Processing Record 7 of Set 10 | half moon bay
# Processing Record 8 of Set 10 | sola
# Processing Record 9 of Set 10 | methven
# Processing Record 10 of Set 10 | saint-nazaire
# Processing Record 11 of Set 10 | nanakuli
# Processing Record 12 of Set 10 | melekhovskaya
# Processing Record 13 of Set 10 | bloomfield
# Processing Record 14 of Set 10 | aflu
# Processing Record 15 of Set 10 | fairbanks
# Processing Record 16 of Set 10 | farrukhnagar
# Processing Record 17 of Set 10 | lunino
# Processing Record 18 of Set 10 | laureles
# Processing Record 19 of Set 10 | labuhan
# Processing Record 20 of Set 10 | imeni poliny osipenko
# Processing Record 21 of Set 10 | wamba
# Processing Record 22 of Set 10 | sedan
# Processing Record 23 of Set 10 | burica
# Processing Record 24 of Set 10 | balykshi
# Processing Record 25 of Set 10 | fiumicino
# Processing Record 26 of Set 10 | dalkola
# Processing Record 27 of Set 10 | friesach
# Processing Record 28 of Set 10 | glamoc
# Processing Record 29 of Set 10 | naze
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | ihosy
# Processing Record 32 of Set 10 | yumen
# Processing Record 33 of Set 10 | rosarito
# Processing Record 34 of Set 10 | samusu
# Processing Record 35 of Set 10 | hualmay
# Processing Record 36 of Set 10 | cauquenes
# Processing Record 37 of Set 10 | ginir
# Processing Record 38 of Set 10 | talara
# Processing Record 39 of Set 10 | obo
# Processing Record 40 of Set 10 | boende
# Processing Record 41 of Set 10 | rio grande
# Processing Record 42 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 10 | kloulklubed
# Processing Record 44 of Set 10 | askino
# Processing Record 45 of Set 10 | hambantota
# Processing Record 46 of Set 10 | san andres
# Processing Record 47 of Set 10 | eldorado
# Processing Record 48 of Set 10 | stepnyak
# Processing Record 49 of Set 10 | qandahar
# Processing Record 50 of Set 10 | purpe
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | baihar
# Processing Record 3 of Set 11 | dingle
# Processing Record 4 of Set 11 | hoi an
# Processing Record 5 of Set 11 | rocha
# Processing Record 6 of Set 11 | itaituba
# Processing Record 7 of Set 11 | trat
# Processing Record 8 of Set 11 | piranhas
# Processing Record 9 of Set 11 | balgazyn
# Processing Record 10 of Set 11 | belmonte
# Processing Record 11 of Set 11 | fort wellington
# Processing Record 12 of Set 11 | sierre
# Processing Record 13 of Set 11 | san quintin
# Processing Record 14 of Set 11 | foeni
# Processing Record 15 of Set 11 | asau
# Processing Record 16 of Set 11 | tambura
# Processing Record 17 of Set 11 | baghdad
# Processing Record 18 of Set 11 | mirnyy
# Processing Record 19 of Set 11 | san angelo
# Processing Record 20 of Set 11 | lufkin
# Processing Record 21 of Set 11 | kentville
# Processing Record 22 of Set 11 | henties bay
# Processing Record 23 of Set 11 | belaya gora
# Processing Record 24 of Set 11 | kenai
# Processing Record 25 of Set 11 | yarkovo
# Processing Record 26 of Set 11 | portland
# Processing Record 27 of Set 11 | bila tserkva
# Processing Record 28 of Set 11 | atar
# Processing Record 29 of Set 11 | henzada
# Processing Record 30 of Set 11 | bandraboua
# Processing Record 31 of Set 11 | tagusao
# Processing Record 32 of Set 11 | saldanha
# Processing Record 33 of Set 11 | kwekwe
# Processing Record 34 of Set 11 | nanzhang
# Processing Record 35 of Set 11 | evensk
# Processing Record 36 of Set 11 | paradwip
# Processing Record 37 of Set 11 | betki
# Processing Record 38 of Set 11 | tavda
# Processing Record 39 of Set 11 | oskemen
# Processing Record 40 of Set 11 | tripoli
# Processing Record 41 of Set 11 | santa isabel
# Processing Record 42 of Set 11 | rio tercero
# Processing Record 43 of Set 11 | mizdah
# Processing Record 44 of Set 11 | mandan
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | honiara
# Processing Record 47 of Set 11 | ulaanbaatar
# Processing Record 48 of Set 11 | iquique
# Processing Record 49 of Set 11 | coahuayana
# Processing Record 50 of Set 11 | bagli
# Processing Record 1 of Set 12 | jinchang
# Processing Record 2 of Set 12 | alexandria
# Processing Record 3 of Set 12 | kyra
# Processing Record 4 of Set 12 | surt
# Processing Record 5 of Set 12 | makung
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | lubu
# Processing Record 8 of Set 12 | port-gentil
# Processing Record 9 of Set 12 | concepcion del oro
# Processing Record 10 of Set 12 | malmyzh
# Processing Record 11 of Set 12 | fort nelson
# Processing Record 12 of Set 12 | vinh
# Processing Record 13 of Set 12 | anadyr
# Processing Record 14 of Set 12 | bathsheba
# Processing Record 15 of Set 12 | galle
# Processing Record 16 of Set 12 | sorvag
# Processing Record 17 of Set 12 | kaeo
# Processing Record 18 of Set 12 | daru
# Processing Record 19 of Set 12 | grindavik
# Processing Record 20 of Set 12 | zalalovo
# Processing Record 21 of Set 12 | newport
# Processing Record 22 of Set 12 | libenge
# Processing Record 23 of Set 12 | bardiyah
# Processing Record 24 of Set 12 | balabac
# Processing Record 25 of Set 12 | alta floresta
# Processing Record 26 of Set 12 | fallon
# Processing Record 27 of Set 12 | alenquer
# Processing Record 28 of Set 12 | thetford mines
# Processing Record 29 of Set 12 | la asuncion
# Processing Record 30 of Set 12 | egvekinot
# Processing Record 31 of Set 12 | oktyabrskoye
# Processing Record 32 of Set 12 | matay
# Processing Record 33 of Set 12 | guatemala
# Processing Record 34 of Set 12 | mesyagutovo
# Processing Record 35 of Set 12 | havre-saint-pierre
# Processing Record 36 of Set 12 | plettenberg bay
# Processing Record 37 of Set 12 | dalianwan
# Processing Record 38 of Set 12 | huilong
# Processing Record 39 of Set 12 | charlestown
# Processing Record 40 of Set 12 | lilongwe
# Processing Record 41 of Set 12 | caconda
# Processing Record 42 of Set 12 | longjiang
# Processing Record 43 of Set 12 | denia
# Processing Record 44 of Set 12 | masvingo
# Processing Record 45 of Set 12 | porto santo
# Processing Record 46 of Set 12 | saint-leu
# Processing Record 47 of Set 12 | farafangana
# Processing Record 48 of Set 12 | schonebeck
# Processing Record 49 of Set 12 | vidim
# Processing Record 50 of Set 12 | inhambane
# Processing Record 1 of Set 13 | outlook
# Processing Record 2 of Set 13 | kombissiri
# Processing Record 3 of Set 13 | tessalit
# Processing Record 4 of Set 13 | imbituba
# Processing Record 5 of Set 13 | oxapampa
# Processing Record 6 of Set 13 | awjilah
# Processing Record 7 of Set 13 | gijon
# Processing Record 8 of Set 13 | saint-michel-des-saints
# Processing Record 9 of Set 13 | the valley
# Processing Record 10 of Set 13 | lere
# Processing Record 11 of Set 13 | simao
# Processing Record 12 of Set 13 | letnyaya stavka
# Processing Record 13 of Set 13 | fortuna
# Processing Record 14 of Set 13 | nicoya
# Processing Record 15 of Set 13 | mandera
# Processing Record 16 of Set 13 | rancho palos verdes
# Processing Record 17 of Set 13 | carupano
# Processing Record 18 of Set 13 | kushima
# Processing Record 19 of Set 13 | pacific grove
# Processing Record 20 of Set 13 | carhuamayo
# Processing Record 21 of Set 13 | kon tum
# Processing Record 22 of Set 13 | aksay
# Processing Record 23 of Set 13 | rakaia
# Processing Record 24 of Set 13 | mahanoro
# Processing Record 25 of Set 13 | grand gaube
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Grand Gaube -20.0064  57.6608     75.38        74          13        1.99
#
#   Country                 Date
# 0      MU  2021-11-24 23:22:33

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '11/24/21'

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
